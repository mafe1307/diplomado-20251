# %%
from pathlib import Path

def list_csv_files(directory: str) -> list:
    """List all Python files in the given directory."""
    p = Path(directory)
    return [str(file) for file in p.glob('*.py')]
 
listed_files= list_csv_files('../Datos')

# %%
print(listed_files)
# Out:
# []

# %%
Path_1=Path('..')/'Datos'
listed_files=(list(Path_1.glob('*.csv')))
print(listed_files)
# Out:
# [WindowsPath('../Datos/productos.csv')]

# %%
archivo1 = Path('../Datos/productos.csv')

# %%
print(archivo1.exists())
# Out:
# True

# %%
print(archivo1.stat())
print(archivo1.stem)
print(archivo1.suffix)
print(archivo1.parent)
# Out:
# os.stat_result(st_mode=33206, st_ino=844424930138426, st_dev=1180199225781706506, st_nlink=1, st_uid=0, st_gid=0, st_size=90, st_atime=1766975946, st_mtime=1766968456, st_ctime=1766968456)
# productos
# .csv
# ..\Datos

# %%
archivo2=Path('../docker-compose.yml')
print(archivo2.exists())
# Out:
# True

# %%
print(archivo2.stat())
print(archivo2.stem)
print(archivo2.suffix)
print(archivo2.parent)
# Out:
# os.stat_result(st_mode=33206, st_ino=844424930138429, st_dev=1180199225781706506, st_nlink=1, st_uid=0, st_gid=0, st_size=1015, st_atime=1766975946, st_mtime=1766968456, st_ctime=1766968456)
# docker-compose
# .yml
# ..

# %%
import logging

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

logging.info("Proceso iniciado")
archivo1=Path('../Datos/productos.csv')
if archivo1.exists():
    logging.info(f"El archivo {archivo1} existe.")
    logging.info(f"Tamaño del archivo: {archivo1.stat().st_size} bytes")
    logging.info(f"Nombre del archivo sin extensión: {archivo1.stem}")
    logging.info(f"Extensión del archivo: {archivo1.suffix}")
    logging.info(f"Directorio padre: {archivo1.parent}")
else:
    logging.warning(f"El archivo {archivo1} no existe.")
    logging.error("No se pueden obtener detalles del archivo inexistente.")
# Out:
# 2025-12-28 21:51:05,733 - INFO - Proceso iniciado
# 2025-12-28 21:51:05,736 - INFO - El archivo ..\Datos\productos.csv existe.
# 2025-12-28 21:51:05,737 - INFO - Tamaño del archivo: 90 bytes
# 2025-12-28 21:51:05,739 - INFO - Nombre del archivo sin extensión: productos
# 2025-12-28 21:51:05,740 - INFO - Extensión del archivo: .csv
# 2025-12-28 21:51:05,741 - INFO - Directorio padre: ..\Datos

# %%
import numpy as np
import logging

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

lista_elegibles= [1,2,3,0,0,"0","o","o","o","o"]

logging.info(f"Lista de elegibles: {lista_elegibles}")

## Escogemos dos


elegibles_1 = np.random.choice(lista_elegibles, size=2, replace=False)
logging.info(f"Elegibles 1: {elegibles_1}")

try:
    primer_elemento = int(elegibles_1[0])
    logging.info(f"Primer elemento seleccionado: {primer_elemento}")
    segundo_elemento = int(elegibles_1[1])
    logging.info(f"Segundo elemento seleccionado: {segundo_elemento}")
    
    div= primer_elemento / segundo_elemento
    logging.info(f"Resultado de la división: {div}")
except ZeroDivisionError:
    logging.error("Error: División por cero no permitida.")
except Exception as e:
    logging.error(f"Ocurrió un error inesperado: {e}")
# Out:
# 2025-12-28 22:00:18,619 - INFO - Lista de elegibles: [1, 2, 3, 0, 0, '0', 'o', 'o', 'o', 'o']
# 2025-12-28 22:00:18,622 - INFO - Elegibles 1: ['3' '0']
# 2025-12-28 22:00:18,624 - INFO - Primer elemento seleccionado: 3
# 2025-12-28 22:00:18,626 - INFO - Segundo elemento seleccionado: 0
# 2025-12-28 22:00:18,628 - ERROR - Error: División por cero no permitida.
