# %%
from pathlib import Path

def list_csv_files(directory: str) -> list:
    """List all Python files in the given directory."""
    p = Path(directory)
    return [str(file) for file in p.glob('*.py')]
 
listed_files= list_csv_files('../Datos')

# %%
print(listed_files)
# Out:
# []

# %%
Path_1=Path('..')/'Datos'
listed_files=(list(Path_1.glob('*.csv')))
print(listed_files)
# Out:
# [WindowsPath('../Datos/productos.csv')]

# %%
archivo1 = Path('../Datos/productos.csv')

# %%
print(archivo1.exists())
# Out:
# True

# %%
print(archivo1.stat())
print(archivo1.stem)
print(archivo1.suffix)
print(archivo1.parent)
# Out:
# os.stat_result(st_mode=33206, st_ino=844424930138426, st_dev=1180199225781706506, st_nlink=1, st_uid=0, st_gid=0, st_size=90, st_atime=1766975946, st_mtime=1766968456, st_ctime=1766968456)
# productos
# .csv
# ..\Datos

# %%
archivo2=Path('../docker-compose.yml')
print(archivo2.exists())
# Out:
# True

# %%
print(archivo2.stat())
print(archivo2.stem)
print(archivo2.suffix)
print(archivo2.parent)
# Out:
# os.stat_result(st_mode=33206, st_ino=844424930138429, st_dev=1180199225781706506, st_nlink=1, st_uid=0, st_gid=0, st_size=1015, st_atime=1766975946, st_mtime=1766968456, st_ctime=1766968456)
# docker-compose
# .yml
# ..
